# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fileimport = "parkinsons_updrs.data"

# %%
url = "data.csv"
delimiter = ','

# Read the CSV file

df = pd.read_csv(url, delimiter=delimiter, header=None)
df = df.drop(columns=[0])

df
# Out:
#            1            2             3               4                 5    \
# 0    air_time1  disp_index1  gmrt_in_air1  gmrt_on_paper1  max_x_extension1
# 1         5160     1.25E-05   120.8041741     86.85333376               957
# 2        51980     1.60E-05   115.3182382     83.44868072              1694
# 3         2600     1.03E-05   229.9339973     172.7618583              2333
# 4         2130     1.03E-05   369.4033417     183.1931039              1756
# ..         ...          ...           ...             ...               ...
# 170       2930     1.04E-05   241.7364774      176.115957              1839
# 171       2140     9.33E-06   274.7289642     234.4958021              2053
# 172       3830     8.36E-06    151.536989     171.1046932              1287
# 173       1760     7.96E-06   289.5181946     196.4111376              1674
# 174       2875     8.18E-06   235.7693499     178.2080244              1838
#
# ...
